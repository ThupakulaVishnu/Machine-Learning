# %% [markdown]
# # **Hierarchical Clustering**

# %% [markdown]
# *Importing the libraries*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Mall_Customers.csv")
x=data.iloc[:,[3,4]].values

# %% [markdown]
# ## Using the dendrogram to find the optimal number of clusters

# %%
import scipy.cluster.hierarchy as sch
dendrogram=sch.dendrogram(sch.linkage(x,method="ward"))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# ## Training the Hierarchical Clustering model on the dataset

# %%
from sklearn.cluster import AgglomerativeClustering
ac=AgglomerativeClustering(n_clusters=5,linkage="ward")
y_pred=ac.fit_predict(x)

# %% [markdown]
# ## Visualising the clusters

# %%
plt.scatter(x[y_pred==0,0],x[y_pred==0,1],s=100,c="red",label="Cluster - 0")
plt.scatter(x[y_pred==1,0],x[y_pred==1,1],s=100,c="green",label="Cluster - 1")
plt.scatter(x[y_pred==2,0],x[y_pred==2,1],s=100,c="yellow",label="Cluster - 2")
plt.scatter(x[y_pred==3,0],x[y_pred==3,1],s=100,c="brown",label="Cluster - 3")
plt.scatter(x[y_pred==4,0],x[y_pred==4,1],s=100,c="cyan",label="Cluster - 4")
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
